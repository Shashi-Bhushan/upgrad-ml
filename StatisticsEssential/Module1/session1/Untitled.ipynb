# %%
import numpy as np
import pandas as pd

# %%
ml = pd.read_csv('ml.csv')

# %%
ml.isnull().sum()
# Out:
# YearsOfExp          0
# CompanyName         3
# Title               0
# Field of Study      2
# Major               0
# School Name         0
# Gender             16
# City                0
# State             188
# dtype: int64

# %%
ml.loc[:, 'YearsOfExp'][ml['YearsOfExp'] == '10+'] = '10'

# %%
type(ml['YearsOfExp'][0])
# Out:
# str

# %%
ml['YearsOfExp'].sum()
# Out:
# ''

# %%
pd.to_numeric(ml.YearsOfExp, errors='coerce').fillna(0).astype(np.int64).sum()
# Out:
# 1377

# %%
ml[ml.YearsOfExp == '10'].shape[0]/ml.shape[0]
# Out:
# 0.4174757281553398

# %%
ml['City'] = ml['City ']

# %%
ml.loc[:, 'City'][(ml.City == 'Bengaluru') | (ml.City == 'Bangalore') | (ml.City == 'BANGALORE') | (ml.City == 'BENGALURU') | (ml.City == 'Bangalore, Karnataka, India')] = 'Blr'

# %%
ml.groupby('City').count()
# Out:
#                     YearsOfExp  CompanyName  Title  Field of Study  Major  \
# City
# 0                            5            5      5               5      5
# 110092                       1            1      1               1      1
# Andheri                      1            1      1               1      1
# Bangkok                      1            1      1               1      1
# Bhopal                       1            1      1               1      1
# Bhubaneswar                  2            2      2               2      2
# Blr                        107          104    107             105    107
# CHENNAI                      2            2      2               2      2
# Chennai                      6            6      6               6      6
# Edinburgh                    1            1      1               1      1
# Erlangen                     1            1      1               1      1
# FARIDABAD                    1            1      1               1      1
# ...
